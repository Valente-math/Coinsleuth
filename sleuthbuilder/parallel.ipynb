# %%
import ultimate_sleuthbuilder as usb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import concurrent.futures

# Function to analyze a sequence and return the p-value
def analyze_sequence(seq):
    return usb.analyze_sequence(seq)['p_value']

# Function to perform a single trial
def perform_trial(sample_size, N):
    sequences = [''.join(np.random.choice(['0', '1'], N)) for _ in range(sample_size)]
    with concurrent.futures.ProcessPoolExecutor() as executor:
        p_values = list(executor.map(analyze_sequence, sequences))
    return np.mean(p_values)

# Top-level function to run a single trial (wrapper for ProcessPoolExecutor)
def run_single_trial(args):
    sample_size, N = args
    return perform_trial(sample_size, N)

# Function to run all trials
def run_trials(trials, sample_size, N):
    with concurrent.futures.ProcessPoolExecutor() as executor:
        mean_p_values = list(executor.map(run_single_trial, [(sample_size, N) for _ in range(trials)]))
    return mean_p_values

# Parameters
N = 32 # Sequence length
sample_size = 100 # Sample size
trials = 100 # Number of trials

# Run trials
mean_p_values = run_trials(trials, sample_size, N)

# Create a histogram of the mean chi-squared values
mean_p_values = np.array(mean_p_values)
sample_df = pd.DataFrame(mean_p_values, columns=['Mean P-value'])

# Plotting the histogram
sns.histplot(sample_df['Mean P-value'], bins=30, kde=True)
plt.xlabel('Mean P-value')
plt.ylabel('Frequency')
plt.title('Histogram of Mean P-values')
plt.show()
# Out:
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
# ...
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# HDF5-DIAG: Error detected in HDF5 (1.14.2) thread 1:
#   #000: H5F.c line 836 in H5Fopen(): unable to synchronously open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5F.c line 796 in H5F__open_api_common(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3863 in H5VL_file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #003: H5VLcallback.c line 3675 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #004: H5VLnative_file.c line 128 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1911 in H5F_open(): unable to lock the file
#     major: File accessibility
#     minor: Unable to lock file
#   #006: H5FD.c line 2412 in H5FD_lock(): driver lock request failed
#     major: Virtual File Layer
#     minor: Unable to lock file
#   #007: H5FDsec2.c line 941 in H5FD__sec2_lock(): unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#     major: Virtual File Layer
#     minor: Unable to lock file
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# concurrent.futures.process._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/local/python/3.10.13/lib/python3.10/concurrent/futures/process.py", line 246, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "/usr/local/python/3.10.13/lib/python3.10/concurrent/futures/process.py", line 205, in _process_chunk
#     return [fn(*args) for args in chunk]
#   File "/usr/local/python/3.10.13/lib/python3.10/concurrent/futures/process.py", line 205, in <listcomp>
#     return [fn(*args) for args in chunk]
#   File "/tmp/ipykernel_9648/2551995018.py", line 10, in analyze_sequence
#     return usb.analyze_sequence(seq)['p_value']
#   File "/workspaces/Coinsleuth/sleuthbuilder/ultimate_sleuthbuilder.py", line 254, in analyze_sequence
#     with pd.HDFStore(db_path, mode='a') as store:
#   File "/home/codespace/.cache/pypoetry/virtualenvs/sleuthbuilder-oEn7SC1Y-py3.10/lib/python3.10/site-packages/pandas/io/pytables.py", line 585, in __init__
#     self.open(mode=mode, **kwargs)
#   File "/home/codespace/.cache/pypoetry/virtualenvs/sleuthbuilder-oEn7SC1Y-py3.10/lib/python3.10/site-packages/pandas/io/pytables.py", line 745, in open
#     self._handle = tables.open_file(self._path, self._mode, **kwargs)
#   File "/home/codespace/.cache/pypoetry/virtualenvs/sleuthbuilder-oEn7SC1Y-py3.10/lib/python3.10/site-packages/tables/file.py", line 294, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/codespace/.cache/pypoetry/virtualenvs/sleuthbuilder-oEn7SC1Y-py3.10/lib/python3.10/site-packages/tables/file.py", line 744, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 512, in tables.hdf5extension.File._g_new
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "H5F.c", line 836, in H5Fopen
#     unable to synchronously open file
#   File "H5F.c", line 796, in H5F__open_api_common
#     unable to open file
#   File "H5VLcallback.c", line 3863, in H5VL_file_open
#     open failed
#   File "H5VLcallback.c", line 3675, in H5VL__file_open
#     open failed
#   File "H5VLnative_file.c", line 128, in H5VL__native_file_open
#     unable to open file
#   File "H5Fint.c", line 1911, in H5F_open
#     unable to lock the file
#   File "H5FD.c", line 2412, in H5FD_lock
#     driver lock request failed
#   File "H5FDsec2.c", line 941, in H5FD__sec2_lock
#     unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#
# End of HDF5 error back trace
#
# Unable to open/create file 'data/ultimate_database.h5'
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/python/3.10.13/lib/python3.10/concurrent/futures/process.py", line 246, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "/usr/local/python/3.10.13/lib/python3.10/concurrent/futures/process.py", line 205, in _process_chunk
#     return [fn(*args) for args in chunk]
#   File "/usr/local/python/3.10.13/lib/python3.10/concurrent/futures/process.py", line 205, in <listcomp>
#     return [fn(*args) for args in chunk]
#   File "/tmp/ipykernel_9648/2551995018.py", line 22, in run_single_trial
#     return perform_trial(sample_size, N)
#   File "/tmp/ipykernel_9648/2551995018.py", line 16, in perform_trial
#     p_values = list(executor.map(analyze_sequence, sequences))
#   File "/usr/local/python/3.10.13/lib/python3.10/concurrent/futures/process.py", line 575, in _chain_from_iterable_of_lists
#     for element in iterable:
#   File "/usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py", line 621, in result_iterator
#     yield _result_or_cancel(fs.pop())
#   File "/usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py", line 319, in _result_or_cancel
#     return fut.result(timeout)
#   File "/usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py", line 458, in result
#     return self.__get_result()
#   File "/usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py", line 403, in __get_result
#     raise self._exception
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "H5F.c", line 836, in H5Fopen
#     unable to synchronously open file
#   File "H5F.c", line 796, in H5F__open_api_common
#     unable to open file
#   File "H5VLcallback.c", line 3863, in H5VL_file_open
#     open failed
#   File "H5VLcallback.c", line 3675, in H5VL__file_open
#     open failed
#   File "H5VLnative_file.c", line 128, in H5VL__native_file_open
#     unable to open file
#   File "H5Fint.c", line 1911, in H5F_open
#     unable to lock the file
#   File "H5FD.c", line 2412, in H5FD_lock
#     driver lock request failed
#   File "H5FDsec2.c", line 941, in H5FD__sec2_lock
#     unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#
# End of HDF5 error back trace
#
# Unable to open/create file 'data/ultimate_database.h5'
# """
#
# The above exception was the direct cause of the following exception:
#
# HDF5ExtError                              Traceback (most recent call last)
# Cell In[4], line 36
#      33 trials = 100 # Number of trials
#      35 # Run trials
# ---> 36 mean_p_values = run_trials(trials, sample_size, N)
#      38 # Create a histogram of the mean chi-squared values
#      39 mean_p_values = np.array(mean_p_values)
#
# Cell In[4], line 27, in run_trials(trials, sample_size, N)
#      25 def run_trials(trials, sample_size, N):
#      26     with concurrent.futures.ProcessPoolExecutor() as executor:
# ---> 27         mean_p_values = list(executor.map(run_single_trial, [(sample_size, N) for _ in range(trials)]))
#      28     return mean_p_values
#
# File /usr/local/python/3.10.13/lib/python3.10/concurrent/futures/process.py:575, in _chain_from_iterable_of_lists(iterable)
#     569 def _chain_from_iterable_of_lists(iterable):
#     570     """
#     571     Specialized implementation of itertools.chain.from_iterable.
#     572     Each item in *iterable* should be a list.  This function is
#     573     careful not to keep references to yielded objects.
#     574     """
# --> 575     for element in iterable:
#     576         element.reverse()
#     577         while element:
#
# File /usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File /usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File /usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# HDF5ExtError: HDF5 error back trace
#
#   File "H5F.c", line 836, in H5Fopen
#     unable to synchronously open file
#   File "H5F.c", line 796, in H5F__open_api_common
#     unable to open file
#   File "H5VLcallback.c", line 3863, in H5VL_file_open
#     open failed
#   File "H5VLcallback.c", line 3675, in H5VL__file_open
#     open failed
#   File "H5VLnative_file.c", line 128, in H5VL__native_file_open
#     unable to open file
#   File "H5Fint.c", line 1911, in H5F_open
#     unable to lock the file
#   File "H5FD.c", line 2412, in H5FD_lock
#     driver lock request failed
#   File "H5FDsec2.c", line 941, in H5FD__sec2_lock
#     unable to lock file, errno = 11, error message = 'Resource temporarily unavailable'
#
# End of HDF5 error back trace
#
# Unable to open/create file 'data/ultimate_database.h5'
